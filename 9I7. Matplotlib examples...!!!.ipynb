# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# # Vertical Bar Chart

# %%
city=['Delhi','Beijing','Washington','Tokyo','Moscow']
Happiness_Index=[60,40,70,65,85]

# %%
plt.bar(city,Happiness_Index,color='pink',edgecolor='red')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(city,Happiness_Index,color='pink',edgecolor='red')
plt.xlabel('City', fontsize=16)
plt.ylabel('Happiness_Index', fontsize=16)
plt.title('Barchart - Happiness index across cities',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Barchart - Happiness index across cities')

# %% [markdown]
# # Horizontal Bar Chart

# %%
plt.barh(city,Happiness_Index,color='blue',edgecolor='black')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(city,Happiness_Index,color='blue',edgecolor='black')
plt.xlabel('Happiness_Index', fontsize=16)
plt.ylabel('City', fontsize=16)
plt.title('Horizontal Barchart - Happiness index across cities',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Horizontal Barchart - Happiness index across cities')

# %% [markdown]
# # Stack bar chart

# %%
city=['Delhi','Beijing','Washington','Tokyo','Moscow']
Gender=['Male','Female']
Happiness_Index_Male=[60,40,70,65,85]
Happiness_Index_Female=[30,60,70,55,75]

# %%
plt.bar(city,Happiness_Index_Male,color='blue',edgecolor='black')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(city,Happiness_Index_Female,color='pink',edgecolor='black',bottom=Happiness_Index_Male)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(city,Happiness_Index_Male,color='blue',edgecolor='black')
plt.bar(city,Happiness_Index_Female,color='pink',edgecolor='black',bottom=Happiness_Index_Male)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(city,Happiness_Index_Male,color='blue',edgecolor='black')
plt.bar(city,Happiness_Index_Female,color='pink',edgecolor='black',bottom=Happiness_Index_Male)
plt.xlabel('City', fontsize=16)
plt.ylabel('Happiness_Index', fontsize=16)
plt.title('Stacked Barchart - Happiness index across cities',fontsize=18)
plt.legend(Gender,loc=2) #Try changeing loc number from 1 to 10

# %% [markdown]
# # Histogram

# %%
values = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
plt.hist(values,5, histtype='step', align='mid', color='green')

# Try changing number 8 which a bin size to different numbers
# Out:
# (array([2., 2., 5., 8., 3.]),
#  array([24. , 38.8, 53.6, 68.4, 83.2, 98. ]),
#  [<matplotlib.patches.Polygon at 0x1f622a5c670>])

# %% [markdown]
# Here, second argument is the number of bins, histype=’step’: it plots the histogram in step format, aligned to mid, color chosen is green.

# %%
plt.hist(values,8, histtype='step', align='mid', color='green', label='Test Score Data')
plt.legend(loc=2)
#argument loc=2 plots the legend on the top left corner.
plt.title('Histogram of score')
# Out:
# Text(0.5, 1.0, 'Histogram of score')

# %% [markdown]
# # #Histogram with bar Filled:

# %%
values = [82,76,24,40,67,62,75,78,71,32,98,89,78,67,72,82,87,66,56,52]
plt.hist(values,6, histtype='bar', color='cyan', label='Test score Data',edgecolor='black')
#Argument histype=’bar’ plots the histogram in bar filled format.
plt.legend()
plt.title('Histogram of score')
# Out:
# Text(0.5, 1.0, 'Histogram of score')

# %% [markdown]
# # Box Plot

# %%
value1=[82,76,-2,40,67,62,75,78,71,13,98,89,78,67,72,82,87,66,56,52]
value2=[62,5,91,-50,36,32,96,95,3,-105,95,32,27,55,100,-17,71,11,37,21]
value3=[23,89,12,78,72,89,25,69,68,86,19,49,15,16,16,75,65,31,25,52]
value4=[59,73,70,16,81,61,88,98,10,87,29,72,16,23,72,88,78,99,75,30]

# %%
box_plot_data=[value1,value2,value3,value4]
plt.boxplot(box_plot_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f622bbbcd0>,
#   <matplotlib.lines.Line2D at 0x1f622bcc0a0>,
#   <matplotlib.lines.Line2D at 0x1f622bd8670>,
#   <matplotlib.lines.Line2D at 0x1f622bd8a00>,
#   <matplotlib.lines.Line2D at 0x1f622be2fa0>,
#   <matplotlib.lines.Line2D at 0x1f622bec370>,
#   <matplotlib.lines.Line2D at 0x1f622bf9910>,
#   <matplotlib.lines.Line2D at 0x1f622bf9ca0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f622bcc430>,
#   <matplotlib.lines.Line2D at 0x1f622bcc7c0>,
#   <matplotlib.lines.Line2D at 0x1f622bd8d90>,
#   <matplotlib.lines.Line2D at 0x1f622be2160>,
#   <matplotlib.lines.Line2D at 0x1f622bec700>,
#   <matplotlib.lines.Line2D at 0x1f622beca90>,
#   <matplotlib.lines.Line2D at 0x1f622c05070>,
#   <matplotlib.lines.Line2D at 0x1f622c05400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f622bbb910>,
#   <matplotlib.lines.Line2D at 0x1f622bd82e0>,
#   <matplotlib.lines.Line2D at 0x1f622be2c10>,
#   <matplotlib.lines.Line2D at 0x1f622bf9580>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f622bccb50>,
#   <matplotlib.lines.Line2D at 0x1f622be24f0>,
#   <matplotlib.lines.Line2D at 0x1f622bece20>,
#   <matplotlib.lines.Line2D at 0x1f622c05790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f622bccee0>,
#   <matplotlib.lines.Line2D at 0x1f622be2880>,
#   <matplotlib.lines.Line2D at 0x1f622bf91f0>,
#   <matplotlib.lines.Line2D at 0x1f622c05b20>],
#  'means': []}

# %% [markdown]
# # Box plot with fills and labels:

# %%
box_plot_data=[value1,value2,value3,value4]
plt.boxplot(box_plot_data,patch_artist=True,labels=['course1','course2','course3','course4'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f622c704c0>,
#   <matplotlib.lines.Line2D at 0x1f622c70850>,
#   <matplotlib.lines.Line2D at 0x1f622c7bc40>,
#   <matplotlib.lines.Line2D at 0x1f622c7bfd0>,
#   <matplotlib.lines.Line2D at 0x1f622c92460>,
#   <matplotlib.lines.Line2D at 0x1f622c927f0>,
#   <matplotlib.lines.Line2D at 0x1f622ca1c70>,
#   <matplotlib.lines.Line2D at 0x1f622cac040>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f622c70be0>,
#   <matplotlib.lines.Line2D at 0x1f622c70f70>,
#   <matplotlib.lines.Line2D at 0x1f622c893a0>,
#   <matplotlib.lines.Line2D at 0x1f622c89730>,
#   <matplotlib.lines.Line2D at 0x1f622c92b80>,
#   <matplotlib.lines.Line2D at 0x1f622c92f10>,
#   <matplotlib.lines.Line2D at 0x1f622cac3d0>,
#   <matplotlib.lines.Line2D at 0x1f622cac760>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x1f622c1c4c0>,
#   <matplotlib.patches.PathPatch at 0x1f622c7b8e0>,
#   <matplotlib.patches.PathPatch at 0x1f622c92100>,
#   <matplotlib.patches.PathPatch at 0x1f622ca1850>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f622c7b340>,
#   <matplotlib.lines.Line2D at 0x1f622c89ac0>,
#   <matplotlib.lines.Line2D at 0x1f622ca12e0>,
#   <matplotlib.lines.Line2D at 0x1f622cacaf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f622c7b670>,
#   <matplotlib.lines.Line2D at 0x1f622c89e50>,
#   <matplotlib.lines.Line2D at 0x1f622ca1670>,
#   <matplotlib.lines.Line2D at 0x1f622cace80>],
#  'means': []}

# %% [markdown]
# argument "patch_artist=True", fills the boxplot and argument "label" takes label to be plotted.

# %% [markdown]
# # Horizontal box plot with different colors:

# %%
box_plot_data=[value1,value2,value3,value4]
box = plt.boxplot(box_plot_data,vert=0,patch_artist=True,
                labels=['course1','course2','course3','course4'])

#Adding argument vert =0 plots the horizontal box plot.

colors = ['cyan', 'lightblue', 'lightgreen', 'tan']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# %% [markdown]
# Colors array takes four different colors and passes them to four different boxes of the boxplot with patch.set_facecolor() function.

# %% [markdown]
# # Line plot or chart

# %%
values = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9]
plt.plot(values)

# %% [markdown]
# # Multiple Line charts with legends and Labels

# %%
# lets take an example of sale of units in 2016 and 2017 to demonstrate line charts.

sales1 = [1, 5, 8, 9, 7, 11, 8, 12, 14, 9, 5,9] #2016
sales2 = [3, 7, 9, 6, 4, 5, 14, 7, 6, 16, 12,10] #2017

# %%
line_chart1 = plt.plot( sales1,range(1,13))
line_chart2 = plt.plot( sales2,range(1,13))

# %%
line_chart1 = plt.plot( sales1,range(1,13))
line_chart2 = plt.plot( sales2,range(1,13))
plt.title('Monthly sales of 2016 and 2017')
plt.xlabel('Sales')
plt.ylabel('Month')
plt.legend(['year 2016', 'year 2017'], loc=4)

# %% [markdown]
# # Significance of x and y axis in line chart

# %%
line_chart1 = plt.plot(range(1,13), sales1,'--', scalex=True)
line_chart2 = plt.plot(range(1,13), sales2,':')
plt.title('Monthly sales of 2016 and 2017')
plt.xlabel('Moths')
plt.ylabel('Sales')
plt.legend(['year 2016', 'year 2017'], loc=4)

# %% [markdown]
# # Pie Chart

# %%
values = [60, 80, 90, 55, 10, 30]
Col = ['b', 'g', 'r', 'c', 'm', 'y']
labels = ['US', 'UK', 'India', 'Germany', 'Australia', 'South Korea']
Exp = (0.5, 0, 0, 0, 0, 0)

# %%
plt.pie(values, colors=Col, labels= values,explode=Exp,counterclock=False, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f623facc70>,
#   <matplotlib.patches.Wedge at 0x1f623fbb460>,
#   <matplotlib.patches.Wedge at 0x1f623fbbbb0>,
#   <matplotlib.patches.Wedge at 0x1f623fc72e0>,
#   <matplotlib.patches.Wedge at 0x1f623fc7a30>,
#   <matplotlib.patches.Wedge at 0x1f623fd61c0>],
#  [Text(1.338352210081018, -0.8768200281535861, '60'),
#   Text(-0.3900654016728485, -1.0285178571214986, '80'),
#   Text(-0.9975617655541599, 0.4635412860840635, '90'),
#   Text(0.2889782482596245, 1.0613630726724945, '55'),
#   Text(0.8576418857711532, 0.6888035973852782, '10'),
#   Text(1.0540704579497828, 0.3145400923213692, '30')])

# %%
plt.pie(values, colors=Col, labels= values,explode=Exp,counterclock=False, shadow=True)
plt.title('Population Density Index')
plt.legend(labels,loc=3)

# %% [markdown]
# # Pie chart in with percentage values

# %%
values = [60, 80, 90, 55, 10, 30]
colors = ['b', 'g', 'r', 'c', 'm', 'y']
labels = ['US', 'UK', 'India', 'Germany', 'Australia', 'South Korea']
explode = (0.0, 0, 0, 0, 0.75, 0)
plt.pie(values, colors=colors, labels=labels,
explode=explode, autopct='%1.3f%%', shadow=True)
plt.title('Population Density Index')
# Out:
# Text(0.5, 1.0, 'Population Density Index')

# %% [markdown]
# # Scatter Plot

# %%
weight1=[63.3,57,64.3,63,71,61.8,62.9,65.6,64.8,63.1,68.3,69.7,65.4,66.3,60.7]
height1=[156.3,100.7,114.8,156.3,237.1,123.9,151.8,164.7,105.4,136.1,175.2,137.4,164.2,151,124.3]

# %%
plt.scatter(height1,weight1,c='b',marker='*')
plt.xlabel('height', fontsize=16)
plt.ylabel('weight', fontsize=16)
plt.title('scatter plot - height vs weight',fontsize=20)
# Out:
# Text(0.5, 1.0, 'scatter plot - height vs weight')

# %% [markdown]
# # Scatter plot for three different groups

# %%
weight1=[57,58.2,58.6,59.6,59.8,60.2,60.5,60.6,60.7,61.3,61.3,61.4,61.8,61.9,62.3]
height1=[100.7,195.6,94.3,127.1,111.7,159.7,135,149.9,124.3,112.9,176.7,110.2,123.9,161.9,107.8]
 
weight2=[62.9,63,63.1,63.2,63.3,63.4,63.4,63.4,63.5,63.6,63.7,64.1,64.3,64.3,64.7,64.8,65]
height2=[151.8,156.3,136.1,124.2,156.3,130,181.2,255.9,163.1,123.1,119.5,179.9,114.8,174.1,108.8,105.4,141.4]
 
 
weight3=[69.2,69.2,69.4,69.7,70,70.3,70.8,71,71.1,71.7,71.9,72.4,73,73.1,76.2]
height3=[166.8,172.9,193.8,137.4,162.4,137.1,169.1,237.1,189.1,179.3,174.8,213.3,198,191.1,220.6]

# %%
import numpy as np
weight=np.concatenate((weight1,weight2,weight3))
height=np.concatenate((height1,height2,height3))
print(weight)
# Out:
# [57.  58.2 58.6 59.6 59.8 60.2 60.5 60.6 60.7 61.3 61.3 61.4 61.8 61.9
#  62.3 62.9 63.  63.1 63.2 63.3 63.4 63.4 63.4 63.5 63.6 63.7 64.1 64.3
#  64.3 64.7 64.8 65.  69.2 69.2 69.4 69.7 70.  70.3 70.8 71.  71.1 71.7
#  71.9 72.4 73.  73.1 76.2]

# %%
color_array = ['b'] * 15 + ['g'] * 17 + ['r'] * 15

# %%
plt.scatter(weight, height, marker='*', c=color_array)

plt.xlabel('weight', fontsize=16)
plt.ylabel('height', fontsize=16)
plt.title('grouped scatter plot - height vs weight',fontsize=20)
# Out:
# Text(0.5, 1.0, 'grouped scatter plot - height vs weight')
